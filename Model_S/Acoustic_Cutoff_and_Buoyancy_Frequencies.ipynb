# %%
# read in binary data
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pickle
import sys, os
sys.path.append(os.environ['raco'])
from common import dotdict, g_univ, inds_from_vals
f = open("Model_S.pkl", "rb")
di = dotdict(pickle.load(f))
f.close()

# %%
di.keys()
# Out:
# dict_keys(['msun', 'rsun', 'lsun', 'zsun', 'x0sun', 'alphasun', 'agesun', 'rr', 'lnq', 'grav', 'tmp', 'prs', 'rho', 'xfrac', 'lum', 'opa', 'eps', 'gamma', 'gamma_ad', 'delta', 'c_p', 'mue', 'ne', 'dsdr', 'nsq', 'zfrac', 'Ne', 'nu', 'kappa', 'eta', 'prm', 'pr', 'drhodr', 'dtmpdr', 'dprsdr', 'dlnrho', 'dlntmp', 'dlnprs', 'gas_constant', 'ircut', 'rcut', 'irbcz', 'rbcz', 'frad', 'heat', 'rtach', 'dtach', 'irtach', 'irtach1', 'irtach2', 'rtach1', 'rtach2', 'rrrz', 'nr', 'nrrz', 'reta', 'etaconst', 'iretaconst', 'retaconst'])

# %%
# all right let's plot some buoyancy frequency

# %%
plt.close()
plt.plot(di.rr, di.nsq)
plt.xlabel('r [cm]')
plt.ylabel('N^2')
plt.yscale('log')
plt.ylim(1e-8,1e-5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1e-08, 1e-05)

# %%
plt.close()
plt.plot(di.rr, di.nsq)
plt.xlabel('r [cm]')
plt.ylabel('N^2')
#plt.yscale('log')
plt.ylim(0,1e-5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 1e-05)

# %%
# all right let's plot some acoustic cutoff frequency

# %%
csq = di.dlnprs/di.dlnrho*di.prs/di.rho
Hprs = -1./di.dlnprs
omcasq = csq/Hprs**2

plt.close()
plt.plot(di.rr, omcasq)
plt.xlabel('r [cm]')
plt.ylabel('w_ca^2')
plt.yscale('log')
#plt.ylim(1e-8,1e-5)
# Out:
# /var/folders/ss/ddlz1pd53ls6zf26gks96rgc0000gp/T/ipykernel_37217/1036648791.py:5: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close()
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
plt.plot(di.rr, omcasq)
plt.xlabel('r [cm]')
plt.ylabel('w_ca^2')
#plt.yscale('log')
plt.ylim(0,5e-5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 5e-05)

# %%
# now the ratio

# %%
plt.close()
plt.plot(di.rr, di.nsq/omcasq)
plt.xlabel('r [cm]')
plt.ylabel('N^2/w_ca^2')
#plt.yscale('log')
plt.ylim(0,0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 0.3)

# %%
#  plot just the sound speed
plt.close()
plt.plot(di.rr, np.sqrt(csq))
plt.xlabel('r [cm]')
plt.ylabel('|cs|')
plt.yscale('log')
#plt.ylim(1e-8,1e-5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#  plot solar sound crossing time, in minutes
plt.close()
plt.plot(di.rr, 2*di.rsun/np.sqrt(csq)/60.)
plt.xlabel('r [cm]')
plt.ylabel('sound crossing time (minutes)')
#plt.yscale('log')
plt.ylim(0,300)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 300.0)

# %%
# finally, try plotting instead normalized buoyancy frequency
hprs = - 1./di.dlnprs
plt.close()
plt.plot(di.rr, di.nsq/di.grav*hprs)
plt.xlabel('r [cm]')
plt.ylabel('N^2 / (g/H_P)')
#plt.yscale('log')
plt.ylim(0,0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 0.3)
